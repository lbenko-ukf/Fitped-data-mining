# %%
import pandas as pd

# %%
# read the log file
columns = ['IP','Cookie','User','Datetime','TMZ','Request','ReturnCode','Bytes','Referrer','UserAgent']
df = pd.read_csv('Log_file.log', header=None, names=columns, sep=' ')

# %%
df.head()
# Out:
#              IP Cookie User               Datetime     TMZ  \
# 0  193.87.12.30      -    -  [19/Feb/2020:06:25:50  +0100]
# 1  193.87.12.30      -    -  [19/Feb/2020:06:25:55  +0100]
# 2  193.87.12.30      -    -  [19/Feb/2020:06:25:56  +0100]
# 3  193.87.12.30      -    -  [19/Feb/2020:06:25:57  +0100]
# 4  193.87.12.30      -    -  [19/Feb/2020:06:25:49  +0100]
#
#                                 Request  ReturnCode  Bytes Referrer  \
# 0  GET /navbar/navbar-ukf.html HTTP/1.0         200   7584        -
# 1  GET /navbar/navbar-ukf.html HTTP/1.0         200   7584        -
# 2  GET /navbar/navbar-ukf.html HTTP/1.0         200   7584        -
# 3  GET /navbar/navbar-ukf.html HTTP/1.0         200   7584        -
# 4                        GET / HTTP/1.1         200  20925        -
#
#           UserAgent
# 0                 -
# 1                 -
# 2                 -
# 3                 -
# 4  libwww-perl/6.08

# %% [markdown]
# # Data preprocessing

# %%
# data cleaning
suffix = (".jpg", ".jpeg",".png",".gif",".bmp",".css",".flv",".ico",".swf",".rss",".xml",".cur",".js",".json",".svg",
           ".woff",".eot",".font","POST","HEAD",".JPG")

for s in suffix:
    df.drop(df[df['Request'].str.contains(s)].index, inplace=True)


df.drop(df.loc[df.ReturnCode>=400].index, inplace=True)
df.drop(df.loc[df.ReturnCode<200].index, inplace=True)

# %%
robotstxt = df[df['Request'].str.contains("robots.txt")]
ips = robotstxt['IP']
print(ips.shape)

for ip in ips:
    df.drop(df[df['IP'].str.contains(ip)].index, inplace=True)
# Out:
# (333,)

# %%
df.drop(df[df['UserAgent'].str.contains('bot')].index, inplace=True)
df.drop(df[df['UserAgent'].str.contains('crawl')].index, inplace=True)
df.drop(df[df['UserAgent'].str.contains('spider')].index, inplace=True)

# %%
req_tab = pd.crosstab(index=df['Request'], columns="count")
req_tab = req_tab.sort_values(by=["count"], ascending=False)
req_tab.head(15)
# Out:
# col_0                                               count
# Request
# GET /navbar/navbar-ukf.html HTTP/1.0                24854
# GET / HTTP/1.1                                       5534
# GET /index.php?option=com_acymailing&ctrl=cron ...   1440
# GET /univerzita/kontakt/adresar-osob HTTP/1.1         495
# GET /verejnost/aktuality/foto/image?view=image&...    319
# GET /prijimacie-konanie/prihlasovanie-sa-na-stu...    297
# GET /verejnost/aktuality/foto/predaj20 HTTP/1.1       281
# GET /images/oznamy/2020_Oznamy/Univerzita_Kon%C...    250
# GET /verejnost/aktuality/foto/image?view=image&...    238
# GET /fakulty-a-sucasti/filozoficka-fakulta HTTP...    215
# GET /verejnost/aktuality/foto/image?view=image&...    213
# GET /fakulty-a-sucasti/pedagogicka-fakulta HTTP...    190
# GET /studium/organizacia-studia/harmonogram-aka...    180
# GET /verejnost/aktuality/foto/image?view=image&...    174
# GET /fakulty-a-sucasti HTTP/1.1                       171

# %%
df.drop(df[df['Request'].str.contains('navbar')].index, inplace=True)
df.drop(df[df['Request'].str.contains('cron')].index, inplace=True)

# %%
import datetime

def getMonthNum(month):
    return {
        'Jan': 1,
        'Feb': 2,
        'Mar': 3,
        'Apr': 4,
        'May': 5,
        'Jun': 6,
        'Jul': 7,
        'Aug': 8,
        'Sep': 9,
        'Oct': 10,
        'Nov': 11,
        'Dec': 12
    }.get(month, -1) 

def parseDateToUnix(dat):
    day = dat[1:3]
    month = getMonthNum(dat[4:7])
    year = dat[8:12]
    hour = dat[13:15]
    minute = dat[16:18]
    second = dat[19:21]
    return datetime.datetime(int(year), int(month), int(day), int(hour), int(minute), int(second)).timestamp()

# %%
df['Unixtime']=df.apply(lambda row: parseDateToUnix(row['Datetime']), axis=1)

# %%
df = df.sort_values(by=["IP", "UserAgent", "Unixtime"])

# %%
# User identification

user = []
ip_before = "null"
agent_before = "null"
usid = 1
for ip,agent in zip(df['IP'],df['UserAgent']):
    if ip_before!="null":
        if ip_before==ip and agent_before==agent:
            user.append(usid)
        else:
            usid+=1
            user.append(usid)
    else:
        user.append(usid)
    ip_before = ip
    agent_before = agent

df['UserID'] = user

# %%
length = []
unxtm_before = -1
usr_before = -1
for unxtm,usr in zip(df['Unixtime'],df['UserID']):
    if usr_before!=-1:
        if usr==usr_before:
            unx_dif = unxtm-unxtm_before
            if unx_dif<=3600:
                length.append(unx_dif)
            else:
                length.append(None)
        else:
            length.append(None)
    unxtm_before = unxtm
    usr_before = usr

length.append(None)
df['Length'] = length

# %%
uppQ = df['Length'].quantile(0.75)
lowQ = df['Length'].quantile(0.25)
Q = uppQ + 1.5 * (uppQ-lowQ)

sttQ = []
usr_before = -1
length_before = -1
stQ = 1
for length,usr in zip(df['Length'],df['UserID']):
    if usr_before!=-1:
        if usr==usr_before:
            if length_before<=Q:
                sttQ.append(stQ)
            else:
                stQ+=1
                sttQ.append(stQ)
        else:
            stQ+=1
            sttQ.append(stQ)
    else:
        sttQ.append(stQ)
    usr_before = usr
    length_before = length

df['STT_Q'] = sttQ

# %%
# data transformation
def parseCategory(req):
    if(req=="GET / HTTP/1.1"): 
        return "home"
    strng = req.split("/") 
    if len(strng)>2:
        out = strng[1].replace(" HTTP","")
        if(out=="en"):
            return "home"
        else:
            return out
    

df['Category'] = df.apply(lambda row: parseCategory(row['Request']), axis=1)

# %%
req_tab = pd.crosstab(index=df['Category'], columns="count")
req_tab = req_tab.sort_values(by=["count"], ascending=False)
req_tab.head(15)
# Out:
# col_0               count
# Category
# verejnost            6966
# home                 5947
# fakulty-a-sucasti    1283
# univerzita           1269
# images                997
# prijimacie-konanie    897
# studium               833
# media-a-marketing     246
# administrator         227
# component             217
# helpdesk              112
# oznamy                107
# tz                    107
# mojaukf               104
# ubytovanie             99

# %%
def updateCategory(cat):
    if(cat=="verejnost" or cat=="home" or cat=="fakulty-a-sucasti" or cat=="univerzita" or cat=="images" 
       or cat=="prijimacie-konanie" or cat=="studium" or cat=="media-a-marketing" or cat=="administrator" or cat=="component"):
        return cat
    else:
        return "other"

df['Category'] = df.apply(lambda row: updateCategory(row['Category']), axis=1)

# %%
df.Category.unique()
# Out:
# array(['home', 'univerzita', 'other', 'fakulty-a-sucasti', 'studium',
#        'verejnost', 'images', 'component', 'prijimacie-konanie',
#        'media-a-marketing', 'administrator'], dtype=object)

# %%
req_tab = pd.crosstab(index=df['STT_Q'], columns="count")
req_tab = req_tab.sort_values(by=["count"], ascending=False)
req_tab.head(5)
# Out:
# col_0  count
# STT_Q
# 1803     204
# 4107     165
# 2129     165
# 435      132
# 2785     128

# %%
sess = df.sort_values('STT_Q').groupby('STT_Q')['Category'].apply(lambda df: df.reset_index(drop=True)).unstack()
sess
# Out:
#                       0                   1                  2      3    \
# STT_Q
# 1                    home                 NaN                NaN    NaN
# 2                    home                 NaN                NaN    NaN
# 3                    home                 NaN                NaN    NaN
# 4                    home                 NaN                NaN    NaN
# 5                    home                 NaN                NaN    NaN
# ...                   ...                 ...                ...    ...
# 8002                other  prijimacie-konanie  fakulty-a-sucasti  other
# 8003                 home                home                NaN    NaN
# 8004                 home                 NaN                NaN    NaN
# 8005            verejnost               other                NaN    NaN
# 8006   prijimacie-konanie                 NaN                NaN    NaN
#
#          4                  5      6                  7                  8    \
# STT_Q
# 1        NaN                NaN    NaN                NaN                NaN
# 2        NaN                NaN    NaN                NaN                NaN
# 3        NaN                NaN    NaN                NaN                NaN
# 4        NaN                NaN    NaN                NaN                NaN
# 5        NaN                NaN    NaN                NaN                NaN
# ...      ...                ...    ...                ...                ...
# 8002   other  fakulty-a-sucasti  other  fakulty-a-sucasti  fakulty-a-sucasti
# 8003     NaN                NaN    NaN                NaN                NaN
# 8004     NaN                NaN    NaN                NaN                NaN
# 8005     NaN                NaN    NaN                NaN                NaN
# 8006     NaN                NaN    NaN                NaN                NaN
#
#                      9    ...  194  195  196  197  198  199  200  201  202  \
# STT_Q                     ...
# 1                    NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2                    NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3                    NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                    NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5                    NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 8002   fakulty-a-sucasti  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8003                 NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8004                 NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8005                 NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8006                 NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        203
# STT_Q
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# ...    ...
# 8002   NaN
# 8003   NaN
# 8004   NaN
# 8005   NaN
# 8006   NaN
#
# [8006 rows x 204 columns]

# %% [markdown]
# # Data analysis

# %%
from mlxtend.frequent_patterns import apriori, association_rules, fpgrowth

# %%
items = df.Category.unique()

# %%
itemset = set(items)
encoded_vals = []
for index, row in sess.iterrows():
    rowset = set(row) 
    labels = {}
    uncommons = list(itemset - rowset)
    commons = list(itemset.intersection(rowset))
    for uc in uncommons:
        labels[uc] = 0
    for com in commons:
        labels[com] = 1
    encoded_vals.append(labels)
encoded_vals[0]

ohe_df = pd.DataFrame(encoded_vals)

# %%
freq_items = apriori(ohe_df, min_support=0.01, use_colnames=True, verbose=1)
freq_items = freq_items.sort_values(by=["support"], ascending=False)
freq_items.head()
# Out:
# Processing 51 combinations | Sampling itemset size 3
#     support             itemsets
# 9  0.545966               (home)
# 2  0.125781          (verejnost)
# 4  0.119910              (other)
# 6  0.111167         (univerzita)
# 8  0.102798  (fakulty-a-sucasti)

# %%
rules = association_rules(freq_items, metric="support", min_threshold=0.01)
rules = rules.sort_values(by=["support"], ascending=False)
rules.head()
# Out:
#            antecedents          consequents  antecedent support  \
# 0               (home)  (fakulty-a-sucasti)            0.545966
# 1  (fakulty-a-sucasti)               (home)            0.102798
# 2               (home)         (univerzita)            0.545966
# 3         (univerzita)               (home)            0.111167
# 4               (home)          (verejnost)            0.545966
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.102798  0.038346    0.070236  0.683240 -0.017778    0.964978
# 1            0.545966  0.038346    0.373026  0.683240 -0.017778    0.724167
# 2            0.111167  0.032975    0.060398  0.543311 -0.027718    0.945968
# 3            0.545966  0.032975    0.296629  0.543311 -0.027718    0.645512
# 4            0.125781  0.031476    0.057653  0.458359 -0.037196    0.927704

# %%
rules = rules.sort_values(by=["lift"], ascending=False)
rules.head()
# Out:
#              antecedents          consequents  antecedent support  \
# 6               (images)          (verejnost)            0.076817
# 7            (verejnost)             (images)            0.125781
# 21             (studium)             (images)            0.072571
# 20              (images)            (studium)            0.076817
# 16  (prijimacie-konanie)  (fakulty-a-sucasti)            0.076443
#
#     consequent support   support  confidence      lift  leverage  conviction
# 6             0.125781  0.023982    0.312195  2.482060  0.014320    1.271028
# 7             0.076817  0.023982    0.190665  2.482060  0.014320    1.140669
# 21            0.076817  0.011491    0.158348  2.061352  0.005917    1.096869
# 20            0.072571  0.011491    0.149593  2.061352  0.005917    1.090572
# 16            0.102798  0.012990    0.169935  1.653094  0.005132    1.080881
